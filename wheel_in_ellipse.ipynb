# %%
from SpiroData import *
from SpiroDraw import *

# %%
from spiro import *

# %%
path='out/Wheels-in-Ellipses/'
fig_number=0

# %%
sd = SpiroData()
f = SpiroFig()
sd.add(wheel_in_ellipse(0,0,wheel=Wheel(0.01,0.0),ellipse=Ellipse(20,0.8,0,pi/2),loops=1))
sd.add(wheel_in_ellipse(0,0,wheel=Wheel(4,3.5),ellipse=Ellipse(20,0.8,0,pi/2),loops=10,invert=True))
for j in range(1): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(4,3.5),ellipse=Ellipse(20,0.8,0,pi/2+pi/20*j),loops=10,invert=False))
f.plot(sd)
f.save_fig(path+f'Ellipse-{fig_number}.png')
fig_number += 1

# %%
sd = SpiroData()
f = SpiroFig()
#sd.add(wheel_in_ellipse(0,0,wheel=Wheel(0.01,0.0),ellipse=Ellipse(20,0.8,0,pi/2),loops=1))
sd.add(wheel_in_ellipse(0,0,wheel=Wheel(11,6),ellipse=Ellipse(20,0.8,0,pi/2),loops=20,invert=True))
for j in range(1): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(6,6),ellipse=Ellipse(20,0.8,0,pi/2+pi/20*j),loops=30,invert=False))
f.plot(sd,color_scheme='time',cmap='magma')
f.save_fig(path+f'Ellipse-{fig_number}.png')
fig_number += 1

# %%
sd = SpiroData()
f = SpiroFig()
for j in range(4): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(4,3.5),ellipse=Ellipse(20,0.8,0,pi/2+pi/40*j),loops=10,invert=False))
f.plot(sd)
f.save_fig(path+f'Ellipse-{fig_number}.png')
fig_number += 1

# %%
sd = SpiroData()
f = SpiroFig()
#for j in range(4): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(4,3.5),ellipse=Ellipse(20,0.5,0,pi/2+pi/40*j),loops=10,invert=True))
for j in range(4): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(12,10),ellipse=Ellipse(20,0.95,0,pi/2+pi/40*j),loops=10,invert=True))
f.plot(sd,color_scheme='s-ripples')
f.save_fig(path+f'Ellipse-{fig_number}.png')
fig_number += 1

# %%
sd = SpiroData()
f = SpiroFig()
sd.add(wheel_in_ellipse(0,0,wheel=Wheel(0.01,0.0),ellipse=Ellipse(20,0.95,0,pi/2),loops=1,invert=False))
for j in range(6): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(2.1,8,pi/10*j),ellipse=Ellipse(20,0.95,0,pi/2+pi/40*j),loops=2,invert=True))
f.plot(sd,color_scheme='cycles')
f.save_fig(path+f'Ellipse-{fig_number}.png')
fig_number += 1

# %%
sd = SpiroData()
f = SpiroFig()
#sd.add(wheel_in_ellipse(0,0,wheel=Wheel(0.01,0.0),ellipse=Ellipse(20,0.85,0,pi/2),loops=1,invert=False))
for j in range(10): sd.add(wheel_in_ellipse(0,0,wheel=Wheel(2.6,15,pi/10*j),ellipse=Ellipse(20.2,0.85,0,pi/2+pi/40*j),loops=4,invert=False))
f.plot(sd,color_scheme='radial',cmap='turbo')
f.save_fig(path+f'Ellipse-{fig_number}.png')
fig_number += 1
