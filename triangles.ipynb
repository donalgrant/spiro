# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
f = SpiroFig()
s = SpiroData()

# %%
f.plot(spiro_eq_triangle(62,Wheel(20,15),orient=0,loops=20,fold=False),color_scheme='radial',cmap='viridis',new_fig=True)
f.plot(spiro_eq_triangle(62,Wheel(7,11),orient=0,loops=20,inside=True),color_scheme='time',cmap='autumn',new_fig=False)

# %%
cs='time'
f.plot(spiro_eq_triangle(62,Wheel(-20,15),orient=0,loops=10,fold=False),color_scheme=cs,cmap='magma',new_fig=True)
f.plot(spiro_eq_triangle(62,Wheel(-20,14),orient=0,loops=10,fold=False),color_scheme=cs,cmap='magma',new_fig=False)
f.plot(spiro_eq_triangle(62,Wheel(-20,13),orient=0,loops=10,fold=False),color_scheme=cs,cmap='magma',new_fig=False)

# %%
f.plot(spiro_eq_triangle(50,Wheel(5,4.5),orient=0,loops=30,fold=True,inside=False),cmap="Oranges",color_scheme='time',  new_fig=True)
f.plot(spiro_eq_triangle(50,Wheel(7,4.0),orient=0,loops=40,fold=False,inside=True),cmap="BuGn",   color_scheme='cycles',new_fig=False)
f.save_fig('triangle.png')

# %%
f.plot(spiro_eq_triangle(50,Wheel(5,4.5),orient=pi,loops=30,fold=True,inside=False),cmap="Oranges",color_scheme='time',  new_fig=True)
f.plot(spiro_eq_triangle(50,Wheel(7,4.0),orient=pi/4,loops=40,fold=False,inside=True),cmap="BuGn",   color_scheme='cycles',new_fig=False)

# %%
f.plot(spiro_eq_triangle(6,Wheel(5.5,3.0),orient=0,loops=70,fold=False,inside=True),new_fig=True)
