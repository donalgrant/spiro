# %%
from pathlib import Path
path='out/Spiro-Strings/'
Path(path).mkdir(parents=True, exist_ok=True)
fig_number=0

# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from spiro_string import *
from polygon import *
S = SpiroData()
F = SpiroFig()
for o in range(10): 
    S.add(spiro_cross(wheel=Wheel(2,5.5,0),orient=pi/40*o,loops=2,fold=False))
#F.plot(S,cmap='turbo',color_scheme='xrand',alpha=0.05)
#SS1=string_offset_pairs(S,step=500,offset=3000)
#SS2=string_dispersing_pairs(S,step=500,step2=500,offset=3000)
#SS3=string_dispersing_links(S,step0=10,step=40,offset=200)
#SS4=strings_from_coord(S,offset=200)
SS5=SpiroData()
SS5.add(strings_from_pts(S,8,nLines=30,offset=30))
SS5.add(strings_from_pts(S,4,nLines=30,offset=10))
SS5.add(strings_from_pts(S,4,nLines=30,offset=50))
#F.plot(SS1,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS2,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS3,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS4,cmap='turbo',color_scheme='l-waves',dot_size=0.1)
F.plot(SS5,cmap='jet',color_scheme='l-waves',dot_size=0.1,new_fig=True)
#F.plot(S,subsample=50,cmap='turbo',color_scheme='yrand',dot_size=10)
#F.plot(string_offset_pairs(S,step=500),
#       cmap='turbo',color_scheme='rrand',dot_size=5,subsample=50)
#F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
#fig_number += 1

# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from spiro_string import *
S = SpiroData()
F = SpiroFig()
for o in range(10): 
    S.add(spiro_cross(wheel=Wheel(2,5.5,0),orient=pi/40*o,loops=2,fold=False))
#F.plot(S,cmap='turbo',color_scheme='xrand',alpha=0.05)
#SS1=string_offset_pairs(S,step=500,offset=3000)
#SS2=string_dispersing_pairs(S,step=500,step2=500,offset=3000)
#SS3=string_dispersing_links(S,step0=10,step=40,offset=200)
#SS4=strings_from_coord(S,offset=200)
SS5=SpiroData()
SS5.add(strings_from_pts(S,8,nLines=30,offset=30))
SS5.add(strings_from_pts(S,4,nLines=30,offset=10))
SS5.add(strings_from_pts(S,4,nLines=30,offset=50))
#F.plot(SS1,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS2,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS3,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS4,cmap='turbo',color_scheme='l-waves',dot_size=0.1)
F.plot(SS5,cmap='turbo',color_scheme='l-waves',dot_size=0.1,new_fig=True)
#F.plot(S,subsample=50,cmap='turbo',color_scheme='yrand',dot_size=10)
#F.plot(string_offset_pairs(S,step=500),
#       cmap='turbo',color_scheme='rrand',dot_size=10,subsample=50)
F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
fig_number += 1

# %%
F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
fig_number += 1

# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from spiro_string import *
S = SpiroData()
F = SpiroFig()
for o in range(10): 
    S.add(spiro_cross(wheel=Wheel(2,5.5,0),orient=pi/40*o,loops=2,fold=False))
#F.plot(S,cmap='turbo',color_scheme='xrand',alpha=0.05)
#SS1=string_offset_pairs(S,step=500,offset=3000)
#SS2=string_dispersing_pairs(S,step=500,step2=500,offset=3000)
#SS3=string_dispersing_links(S,step0=10,step=40,offset=200)
#SS4=strings_from_coord(S,offset=200)
SS5=SpiroData()
SS5.add(strings_from_pts(S,8,nLines=30,offset=30))
SS5.add(strings_from_pts(S,4,nLines=30,offset=30))
SS5.add(strings_from_pts(S,4,nLines=30,offset=30))
#F.plot(SS1,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS2,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS3,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS4,cmap='turbo',color_scheme='l-waves',dot_size=0.1)
F.plot(SS5,cmap='turbo',color_scheme='l-waves',dot_size=0.1,new_fig=True)
#F.plot(S,subsample=50,cmap='turbo',color_scheme='yrand',dot_size=10)
#F.plot(string_offset_pairs(S,step=500),
#       cmap='turbo',color_scheme='rrand',dot_size=10,subsample=50)
F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
fig_number += 1

# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from spiro_string import *
S = SpiroData()
F = SpiroFig()
for o in range(10): 
    S.add(spiro_cross(wheel=Wheel(2,5.5,0),orient=pi/40*o,loops=2,fold=False))
#F.plot(S,cmap='turbo',color_scheme='xrand',alpha=0.05)
#SS1=string_offset_pairs(S,step=500,offset=3000)
#SS2=string_dispersing_pairs(S,step=500,step2=500,offset=3000)
#SS3=string_dispersing_links(S,step0=10,step=40,offset=200)
#SS4=strings_from_coord(S,offset=200)
SS5=SpiroData()
for i in range(6):
    SS5.add(strings_from_pts(S,4,nLines=8,offset=10))
#F.plot(SS1,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS2,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS3,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS4,cmap='turbo',color_scheme='l-waves',dot_size=0.1)
F.plot(SS5,cmap='turbo',color_scheme='l-waves',dot_size=0.1,new_fig=True)
#F.plot(S,subsample=50,cmap='turbo',color_scheme='yrand',dot_size=10)
#F.plot(string_offset_pairs(S,step=500),
#       cmap='turbo',color_scheme='rrand',dot_size=10,subsample=50)
F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
fig_number += 1

# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from spiro_string import *
S = SpiroData()
F = SpiroFig()
for o in range(10): 
    S.add(spiro_cross(wheel=Wheel(2,5.5,0),orient=pi/40*o,loops=2,fold=False))
#F.plot(S,cmap='turbo',color_scheme='xrand',alpha=0.05)
#SS1=string_offset_pairs(S,step=500,offset=3000)
#SS2=string_dispersing_pairs(S,step=500,step2=500,offset=3000)
#SS3=string_dispersing_links(S,step0=10,step=40,offset=200)
#SS4=strings_from_coord(S,offset=200)
SS5=SpiroData()
SS5.add(strings_from_pts(S,70,nLines=8,offset=100,fixed=50))
#F.plot(SS1,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS2,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS3,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS4,cmap='turbo',color_scheme='l-waves',dot_size=0.1)
F.plot(SS5,cmap='turbo',color_scheme='l-waves',dot_size=0.1,new_fig=True)
#F.plot(S,subsample=50,cmap='turbo',color_scheme='yrand',dot_size=10)
#F.plot(string_offset_pairs(S,step=500),
#       cmap='turbo',color_scheme='rrand',dot_size=10,subsample=50)
F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
fig_number += 1

# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from spiro_string import *
S = SpiroData()
F = SpiroFig()
for o in range(10): 
    S.add(spiro_cross(wheel=Wheel(2,5.5,0),orient=pi/40*o,loops=2,fold=False))
#F.plot(S,cmap='turbo',color_scheme='xrand',alpha=0.05)
#SS1=string_offset_pairs(S,step=500,offset=3000)
#SS2=string_dispersing_pairs(S,step=500,step2=500,offset=3000)
#SS3=string_dispersing_links(S,step0=10,step=40,offset=200)
#SS4=strings_from_coord(S,offset=200)
SS5=SpiroData()
SS5.add(strings_from_pts(S,70,nLines=20,offset=30,fixed=50))
#F.plot(SS1,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS2,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS3,cmap='turbo',color_scheme='cycles',dot_size=0.1)
#F.plot(SS4,cmap='turbo',color_scheme='l-waves',dot_size=0.1)
F.plot(SS5,cmap='turbo',color_scheme='l-waves',dot_size=0.1,new_fig=True)
#F.plot(S,subsample=50,cmap='turbo',color_scheme='yrand',dot_size=10)
#F.plot(string_offset_pairs(S,step=500),
#       cmap='turbo',color_scheme='rrand',dot_size=10,subsample=50)
F.save_fig(path+f'Strings-from-Points-{fig_number}.png')
fig_number += 1
