# %%
from spiro import *

# %%
f=SpiroFig()
f.plot(heart(loops=1),cmap='inferno',color_scheme='radial')

# %%
f=SpiroFig()
sd=SpiroData()
sd.add(spiro_arc(0,0,-pi/2,10,1,0.5,loops=0.5,offset=0,invert=True,reverse=True))
sd.add(rotate(10,0,sd.xc(),sd.yc(),pi))
sd.add(spiro_arc(0,0,+pi/2,10,1,0.5,loops=0.5,offset=sd.pc(),invert=False,reverse=False))
f.plot(sd,color_scheme='time')

# %%
f = SpiroFig()
sd = SpiroData()
sd.add(spiro_steps(10.0,-6.0,9.0,1.4,10,offset=pi/40))
f.plot(sd)

# %%
sd.reset()
offset=0
c="inferno"
cs="radial"
w=2.2
pen=1
pen_inc=0.5
depth=-3
for j in range(5):
    for i in range(10):
        sd.add(roll(20,depth,0,20,w,pen+j*pen_inc,offset=offset))
        sd.add(rotate(0,20,sd.xc(),sd.yc(),pi))
        sd.add(spiro_arc(10,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=sd.pc()))
        sd.add(rotate(20,20,sd.xc(),sd.yc(),pi/2))
        sd.add(spiro_arc(30,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=sd.pc()))
        sd.add(rotate(40,20,sd.xc(),sd.yc(),pi))
        sd.add(roll(40,20,20,depth,w,pen+j*pen_inc,offset=sd.pc()))
        sd.add(rotate(20,depth,sd.xc(),sd.yc(),pi/2))
        offset=sd.pc()
        
offset=0
c="inferno"
cs="radial"
w=1.5
pen=w*1.1
pen_inc=0.5
depth=-3
for j in range(1):
    for i in range(22):
        sd.add(roll(20,depth,0,20,w,pen+j*pen_inc,offset=offset,invert=True))
        sd.add(spiro_arc(10,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=sd.pc(),invert=True))
        sd.add(spiro_arc(30,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=sd.pc(),invert=True))
        sd.add(roll(40,20,20,depth,w,pen+j*pen_inc,offset=sd.pc(),invert=True))
        offset=sd.pc()
    
f.plot(sd,cmap=c,color_scheme=cs)

# %%
sd.reset()
R=10.0
w=2.0
pen=1.5
pen_inc=pen/5
offset=0
j=0
for l in range(10):
    sd.add(spiro_arc(0,0,+pi/2,R,w,pen+j*pen_inc,loops=0.5,offset=offset))
    sd.add(rotate(-R,0,sd.xc(),sd.yc(),pi))
    sd.add(spiro_arc(0,0,-pi/2,R,w,pen+j*pen_inc,loops=0.5,offset=sd.pc(),reverse=True,invert=True))
    sd.add(rotate(R,0,sd.xc(),sd.yc(),pi))
    offset=sd.pc()
fig, ax=plt.subplots(figsize=(10,10))
ax.set(aspect=1)
f=SpiroFig(ax)
f.plot(sd,color_scheme='time',new_fig=False)
