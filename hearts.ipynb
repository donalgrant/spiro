# %%
from spiro import *

# %%
heart()

# %%
fig, ax=plt.subplots(figsize=(5,5))
ax.set(aspect=1)
d=spiro_arc(0,0,-pi/2,10,1,0.5,loops=0.5,offset=0,invert=True,reverse=True)
plot_spiro(d,color_scheme='time',ax=ax)
print(d['x'][-1],d['y'][-1])
d=rotate(10,0,d['x'][-1],d['y'][-1],pi)
plot_spiro(d,color_scheme='time',ax=ax)
d=spiro_arc(0,0,pi/2,10,1,0.5,loops=0.5,offset=d['p'][-1],invert=False,reverse=False)
plot_spiro(d,color_scheme='time',ax=ax)
# Out:
# 9.0 0.49999999999999833
# <Axes: >

# %%
plot_spiro(spiro_steps(10.0,-6.0,9.0,1.4,10,offset=pi/40))
# Out:
# <Axes: >

# %%
fig, ax=plt.subplots(figsize=(10,10))
ax.set(aspect=1)
offset=0
c="inferno"
cs="radial"
w=2.2
pen=1
pen_inc=0.5
depth=-3
for j in range(5):
    for i in range(10):
        d=roll(20,depth,0,20,w,pen+j*pen_inc,offset=offset)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=rotate(0,20,d['x'][-1],d['y'][-1],pi)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=spiro_arc(10,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=d['p'][-1])
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=rotate(20,20,d['x'][-1],d['y'][-1],pi/2)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=spiro_arc(30,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=d['p'][-1])
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=rotate(40,20,d['x'][-1],d['y'][-1],pi)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=roll(40,20,20,depth,w,pen+j*pen_inc,offset=d['p'][-1])
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=rotate(20,depth,d['x'][-1],d['y'][-1],pi/2)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        offset=d['p'][-1]
        
offset=0
c="inferno"
cs="radial"
w=1.5
pen=w*1.1
pen_inc=0.5
depth=-3
for j in range(1):
    for i in range(22):
        d=roll(20,depth,0,20,w,pen+j*pen_inc,offset=offset,invert=True)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
#       d=rotate(0,20,d['x'][-1],d['y'][-1],pi)
#        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=spiro_arc(10,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=d['p'][-1],invert=True)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
#        d=rotate(20,20,d['x'][-1],d['y'][-1],pi/2)
 #       plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=spiro_arc(30,20,-pi/2,10,w,pen+j*pen_inc,loops=0.5,offset=d['p'][-1],invert=True)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
#        d=rotate(40,20,d['x'][-1],d['y'][-1],pi)
#        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        d=roll(40,20,20,depth,w,pen+j*pen_inc,offset=d['p'][-1],invert=True)
        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
#        d=rotate(20,depth,d['x'][-1],d['y'][-1],pi/2)
#        plot_spiro(d,ax=ax,cmap=c,color_scheme=cs)
        offset=d['p'][-1]
