# %%
from spiro import *
f = SpiroFig()
s = SpiroData()

# %%
(w,p,o)=(3,2,0)
coords=array([ [-20,0], [0,20], [20,20], [40,0], [20,-20], [0,-20] ])
f.plot(spiro_polygon(coords, 0.01, 0.0, o, 1, offset=0, fold=False, inside=False))
f.plot(spiro_polygon(coords, w, p, o, 10, offset=0, fold=False, inside=False),new_fig=False)
f.plot(spiro_polygon(coords, w, p, o, 10, offset=0, fold=False, inside=True),new_fig=False)

# %%
(w,p,o)=(3,2,0)
coords=array([ [-20,0], [0,20], [20,20], [40,0], [20,-20], [0,-20] ])
f.plot(spiro_polygon(coords, 0.01, 0.0, o, 1, offset=0, fold=True, inside=False))
f.plot(spiro_polygon(coords, w, p, o, 10, offset=0, fold=True, inside=False),new_fig=False)
f.plot(spiro_polygon(coords, 3*w, 2*p, o, 30, offset=0, fold=True, inside=True),new_fig=False)

# %%
(w,p,o)=(3,2,0)
coords=array([ [-20,0], [20,0] ])
f.plot(spiro_polygon(coords, 0.01, 0.0, o, 1, offset=0, fold=True, inside=False))
f.plot(spiro_polygon(coords, w, p, o, 10, offset=0, fold=False, inside=False),new_fig=False)
f.plot(spiro_polygon(coords, 0.01, 0.0, o, 1, offset=0, fold=True, inside=False))
f.plot(spiro_polygon(coords, w, p, o, 10, offset=0, fold=True, inside=False),new_fig=False)

# %%
(R,w,p,o)=(20,3,2,-pi/2)
f.plot(spiro_ngon(7, R, 0.01, 0.0, o, offset=0, loops=1,  fold=False, inside=False))
f.plot(spiro_ngon(7, R, w,    p,   o, offset=0, loops=10, fold=False, inside=False),new_fig=False)
f.plot(spiro_ngon(7, R, w,    p,   o, offset=0, loops=10, fold=False, inside=True), new_fig=False)

# %%
(R,w,p,o)=(20,3,2,-pi/2)
f.plot(spiro_ngon(9, R, 0.01, 0.0, o, offset=0, loops=1,  fold=False, inside=False))
f.plot(spiro_ngon(9, R, w,    p,   o, offset=0, loops=10, fold=True,  inside=False),new_fig=False)
f.plot(spiro_ngon(5, R/2, w,  3*p,   o, offset=0, loops=26, fold=False, inside=True), new_fig=False)

# %%
(R,w,p,o)=(41,5,10,-pi/2)
f.plot(spiro_ngon(5, R, 0.01, 0, o, offset=0, loops=1,  fold=False, inside=False))
for p in np.linspace(15,25,10):
    f.plot(spiro_ngon(5, R, w,    p, o, offset=10*p*pi/180, loops=1, fold=False, inside=True), new_fig=False)
