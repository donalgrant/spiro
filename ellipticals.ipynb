# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
from ellipse import *

# %%
sd = SpiroData()
f = SpiroFig()

# %%
f.plot(spiro_arc(R=20,wheel=Wheel(0.01,0.0)),smooth=True)
for i in range(6): f.plot(elliptical_arc(R=20,wheel=Ellipse(10.23431,0.3,4,pi/3*i),loops=3, inside=True),new_fig=False,smooth=True)
for i in range(6): f.plot(elliptical_arc(R=20,wheel=Ellipse(3.5,0.1,2,0),orient=pi/3*i,loops=4, inside=True),new_fig=False,smooth=True)
f.plot(elliptical_arc(R=20,wheel=Ellipse(3,0.1,4,0),loops=12, inside=False),new_fig=False,smooth=True)

# %%
sd.reset()
sd.add(spiro_arc(R=20,wheel=Wheel(0.01,0.0)))
for i in range(6): sd.add(elliptical_arc(R=20,wheel=Ellipse(10.23431,0.3,4,pi/3*i),loops=3, inside=True))
for i in range(6): sd.add(elliptical_arc(R=20,wheel=Ellipse(3.5,0.1,2,0),orient=pi/3*i,loops=4, inside=True))
sd.add(elliptical_arc(R=20,wheel=Ellipse(3,0.1,4,0),loops=12, inside=False))
f.plot(sd,dot_size=1,color_scheme='radial',cmap='autumn',smooth=False)
f.caption('multiple elliptical arcs')

# %%
f=SpiroFig()
sd=SpiroData()
np.random.seed(12)
ring=10
a=2.5
e=0.6
n=20
bv=[0.9*a+0.03*a*i for i in range(10)]
x0=np.random.standard_normal(n)*2*ring-ring
y0=np.random.standard_normal(n)*2*ring-ring
for o in range(x0.shape[0]):
    o0=np.random.uniform(0,2*pi)
    of0=np.random.uniform(2*pi)
    for i in range(np.random.randint(3,10)): 
        l=max(0.01,0.25+0.05*np.random.standard_normal(1)[0])
#        print(o,i,l)
        sd.add(elliptical_arc(x0=x0[o],y0=y0[o],orient=o0,
                         R=ring,wheel=Ellipse(a,e,bv[i],of0+pi/5*i),loops=l))
f.plot(sd,color_scheme='x-y',cmap='inferno')

# %%
sd.reset()
for p in range(10):
    sd.add(elliptical_arc(x0=0,y0=0,orient=0,R=2.0,wheel=Ellipse(9.5,0.4,5+p/2,0),
                        loops=10,spacing=pi/4000,inside=False))
f.plot(sd,cmap='tab20b',color_scheme='time',alpha=1.0)
f.caption('outside R=2, e=9.5/0.4, step pen from 5 to 10')
f.save_fig('Ellipse-A.png')

# %%
sd.reset()
for j in range(10):
    sd.add(elliptical_arc(x0=-j/3,y0=j/3,orient=0,R=2.0,wheel=Ellipse(6.5,0.3,2,pi/20*j),
                        loops=3,spacing=pi/4000,inside=False))
f.plot(sd,cmap='Dark2',color_scheme='time',dot_size=.1,alpha=1.0)
f.caption('outside R=2.0 (origin stepped), e=6.5/0.3/2 offset stepped')
f.save_fig('Ellipse-B.png')

# %%
f.plot(roll_ellipse(0,0,50,10,Ellipse(1,0.3,1,0)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 f.plot(roll_ellipse(0,0,50,10,Ellipse(1,0.3,1,0)))
#
# File ~/gitdev/donalgrant/spiro/ellipse.py:84, in roll_ellipse(x1, y1, x2, y2, ellipse, start_guard, end_guard, invert)
#      81 iv = -1 if invert else 1
#      83 phi_factor = 1
# ---> 84 time_factor = iv * a
#      86 if invert:
#      87     phi_factor  *= -1
#
# NameError: name 'a' is not defined

# %%
import scipy

# %%
print(4*1*scipy.special.ellipe(0.3**2))

# %%
ellipse = Ellipse(1.0,0.3)

# %%
print(ellipse.c)
