# %%
from SpiroData import *
from SpiroDraw import *
from spiro import *
f = SpiroFig()
s = SpiroData()

# %%
f.plot(spiro_line(50,Wheel(5,4),orient=0,loops=4,fold=False),new_fig=True,color_scheme='time')
f.plot(spiro_line(50,Wheel(5,4),orient=0,loops=4,fold=False),new_fig=False,color_scheme='time',alpha=0.1,subsample=5,dot_size=50)

# %%
f.plot(spiro_line_orig(50,Wheel(5,4),orient=0,loops=1,fold=True,invert=True),new_fig=True,color_scheme='time')

# %%
f.plot(spiro_line(50,Wheel(5,4),orient=pi/4,loops=4,fold=True),new_fig=True)

# %%
c='viridis'
cs='radial'
f.plot(spiro_line(50,Wheel(5,4),orient=0,   loops=4,fold=True),new_fig=True,cmap=c,color_scheme=cs)
for o in range(10): f.plot(spiro_line(50,Wheel(5,4),orient=2*pi/10*o,loops=4,fold=True),new_fig=False,cmap=c,color_scheme=cs)

# %%
f.plot(spiro_line(62,Wheel(-20,15.0),loops=10,fold=False),new_fig=True)
