# %%
from spiro import *
f = SpiroFig()
s = SpiroData()

# %%
f.plot(spiro_line(50,5,4,orient=0,loops=4,fold=False),new_fig=True,color_scheme='time')
f.save_fig('Lines-1.png')

# %%
f.plot(spiro_line_orig(50,5,4,orient=0,loops=1,fold=True,invert=True),new_fig=True,color_scheme='time')

# %%
f.plot(spiro_line(50,5,4,orient=pi/4,loops=4,fold=True),new_fig=True)
f.save_fig('Lines-2.png')

# %%
c='viridis'
cs='radial'
f.plot(spiro_line(50,5,4,orient=0,   loops=4,fold=True),new_fig=True,cmap=c,color_scheme=cs)
for o in range(10): f.plot(spiro_line(50,5,4,orient=2*pi/10*o,loops=4,fold=True),new_fig=False,cmap=c,color_scheme=cs)
f.save_fig('Lines-3.png')

# %%
f.plot(spiro_line(62,-20,15.0,loops=10,fold=False),new_fig=True)
f.save_fig('Lines-4.png')
