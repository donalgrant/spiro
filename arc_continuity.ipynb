# %% [markdown]
# This notebook is being used to work out the continuity across an arc.  May also use it to refactor "spiro" into a shortcut for spiro_arc.

# %%
from spiro import *

# %%
F = SpiroFig()
S = SpiroData()

# %%
S.reset()
r=10
a=1.3
p=2.3
F.plot(spiro_arc(orient=0,R=r,a=0.01,b=0,loops=1,offset=0,invert=False,reverse=False),cmap='hsv',color_scheme='time',new_fig=True)
o=0
for i in range(1):
#    for b in np.linspace(-a,a,40):
#     S.add(spiro_arc(orient=0,R=r,a=a,b=b,loops=0.5,offset=pi/4,invert=True,reverse=False,spacing=0.0001))
    S.add(spiro_arc(orient=0,   R=r,a=a,b=p,loops=0.5,offset=o,     invert=False,reverse=False))
    print(S.pc()*180/pi)
    o=S.pc()
#    S.add(spiro_arc(orient=pi/2,R=r,a=a,b=a,loops=0.5,offset=o,invert=False,reverse=False))
#    for b in np.linspace(-a,a,40):
#        S.add(spiro_arc(orient=pi/2,R=r,a=a,b=b,loops=0.05,offset=o,invert=False,reverse=False))
    S.add(rotate(0,-r,S.xc(),S.yc(),pi))
    print(S.pc()*180/pi)
    # calculate the new offset from the pen and wheel coordinates
    o=arctan2(-(S.xc()-0),S.yc()-(-r-a))
    print(o*180/pi)
#    o=S.pc()
    S.add(spiro_arc(orient=-pi,R=r,a=a,b=p,loops=0.5,offset=o,invert=True,reverse=True))
#    for b in np.linspace(-a,a,40):
#     S.add(spiro_arc(orient=pi/2,R=r,a=a,b=b,loops=0.05,offset=o,invert=True,reverse=True))
#    S.add(rotate(0,r,S.xc(),S.yc(),pi))
    o=S.pc()
    
F.plot(S,new_fig=False,cmap='autumn',color_scheme='time')
#F.plot(spiro_arc(orient=pi,R=10,a=1,b=2,loops=.25,offset=0,invert=True,reverse=True),new_fig=False,cmap="autumn",color_scheme='radial')
# Out:
# 1384.6153846153845
# 90.19823085791971
# -55.6540104496208

# %%
S.reset()
F.plot(spiro_arc(orient=0,R=10,a=0.01,b=0,loops=1,offset=0,invert=False,reverse=False),cmap='hsv',color_scheme='time',new_fig=True)
o=0
r=10
for i in range(1):
    S.add(spiro_arc(orient=0,R=r,a=1.5,b=1.3,loops=0.25,offset=o,invert=False,reverse=False))
    S.add(rotate(r,0,S.xc(),S.yc(),pi))
    S.add(spiro_arc(orient=pi/2,R=-r,a=1.5,b=1.3,loops=0.25,offset=S.pc(),invert=True,reverse=False))
#    S.add(rotate(0,r,S.xc(),S.yc(),pi))
    o=S.pc()
    
F.plot(S,new_fig=False,cmap='autumn',color_scheme='time')
#F.plot(spiro_arc(orient=pi,R=10,a=1,b=2,loops=.25,offset=0,invert=True,reverse=True),new_fig=False,cmap="autumn",color_scheme='radial')

# %%
(x1,y1,x2,y2)=(0,0,30,0)
(a,b)=(2,2)
S.reset()
S.add(roll(x1,y1,x2,y2,0.01,0.0,offset=0,guard=0,invert=False))
S.add(roll(x1,y1,x2,y2,a,b,offset=0,guard=0,invert=False))
o=S.pc()
S.add(rotate(x2,y2,S.xc(),S.yc(),pi))
S.add(roll(x2,y2,x1,y1,a,b,offset=o+pi,guard=0,invert=False))
S.add(rotate(x1,y1,S.xc(),S.yc(),pi))
S.add(roll(x1,y1,x2,y2,a,b,offset=0,guard=0,invert=True))
o = S.pc()
S.add(rotate(x2,y2,S.xc(),S.yc(),-pi))
S.add(roll(x2,y2,x1,y1,a,b,offset=o-pi,guard=0,invert=True))
S.add(rotate(x1,y1,S.xc(),S.yc(),-pi))
F.plot(S)
